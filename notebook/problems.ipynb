# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less or equal than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less or equal than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)
pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# Normal Distribution

# %%
# TODO
from scipy.stats import norm

def dnorm(valor, mu, sigma):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(valor, loc=mu, scale=sigma)

    return result

def pnorm(valor, mu, sigma):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(valor, loc=mu, scale=sigma)

    return result

def qnorm(porcentaje, mu, sigma):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(porcentaje, loc=mu, scale=sigma)

    return result

def rnorm(mu, sigma, tamaño):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc=mu, scale=sigma, size=tamaño)

    return result

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

mu = 0
sigma = 1
valor = np.linspace(-5, 5, 1000)
porcentaje = np.linspace(0.01,0.99,1000)

pmf = dnorm(valor, mu, sigma)
cdf = pnorm(valor, mu, sigma)
ppf = qnorm(porcentaje, mu, sigma)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(valor, pmf, "r-")
axis[1].plot(valor, cdf, "b-")
axis[2].plot(valor, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
#For uniform distribution
from scipy.stats import uniform

def duniform(valor, inicio, final):
    """
    Calculates the point estimate of the uniform distribution
    """
    result = uniform.pdf(valor, loc=inicio, scale=(final - inicio))

    return result

def puniform(valor, inicio, final):
    """
    Calculates the cumulative of the uniform distribution
    """
    result = uniform.cdf(valor, loc=inicio, scale=(final - inicio))

    return result

def quniform(porcentaje, inicio, final):
    """
    Calculates the quantile function from the uniform distribution
    """
    result = uniform.ppf(porcentaje, loc=inicio, scale=(final - inicio))

    return result

def runiform(inicio, final, tamaño):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(loc=inicio, scale=(final - inicio), size=tamaño)

    return result

# %%
import numpy as np
np.random.seed(42)

print(f"Probability that a Uniform dist. takes the value 0: {duniform(0, -1, 1)}")
print(f"Probability that a Uniform dist. will take a value less or equal than 0: {puniform(0, -1, 1)}")
print(f"Which value of a Uniform dist. has a cumulative probability of 0.5? {quniform(0.5, -1, 1)}")
print(f"Generate 2000 random values from a Uniform dist. distribution: {runiform(-1, 1, 2000)}")
# Out:
# Probability that a Uniform dist. takes the value 0: 0.5
# Probability that a Uniform dist. will take a value less or equal than 0: 0.5
# Which value of a Uniform dist. has a cumulative probability of 0.5? 0.0
# Generate 2000 random values from a Uniform dist. distribution: [-0.25091976  0.90142861  0.46398788 ... -0.86208397 -0.88589056
#  -0.43562585]
